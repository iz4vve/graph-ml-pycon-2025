# %%
import os

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

import torch
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader

# %% [markdown]
# ### Load and prepare data

# %%
# Load the elliptic dataset
data_dir = 'data/elliptic_bitcoin_dataset'

node_features = pd.read_csv(f'{data_dir}/elliptic_txs_features.csv', header=None)
edges = pd.read_csv(f'{data_dir}/elliptic_txs_edgelist.csv')
classes = pd.read_csv(f'{data_dir}/elliptic_txs_classes.csv')

# %%
node_features = node_features.set_index(0)
classes = classes.set_index('txId')

# only keep the features that are labeled
labeled_data = classes[classes['class'] != 'unknown']
labeled_data['class'] = labeled_data['class'].map({'1': 1, '2': 0})
# Out:
# /var/folders/fy/81l_ztvn6g91vzn1p0n6ghjr0000gn/T/ipykernel_57635/803600641.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_data['class'] = labeled_data['class'].map({'1': 1, '2': 0})

# %%
tx_map = {tx: i for i, tx in enumerate(sorted(labeled_data.index))}
reversed_tx_map = {i: tx for tx, i in tx_map.items()}

# %%
_nodes = set(labeled_data.index)
edges = edges[(edges.txId1.isin(_nodes)) & (edges.txId2.isin(_nodes))]
node_features = node_features.loc[list(_nodes)]

# %%
# reset indices to 0-based integers
labeled_data.index = labeled_data.index.map(tx_map)
edges['txId1'] = edges['txId1'].map(tx_map)
edges['txId2'] = edges['txId2'].map(tx_map)
node_features.index = node_features.index.map(tx_map)

# %%
labeled_data['class'].value_counts()
# Out:
# class
# 0    42019
# 1     4545
# Name: count, dtype: int64

# %% [markdown]
# # Traditional modeling

# %%
train, test = train_test_split(
    labeled_data,
    test_size=0.2,
    stratify=labeled_data['class'], 
    random_state=42
)
train.shape, test.shape
# Out:
# ((37251, 1), (9313, 1))

# %%
scaler = StandardScaler()

train_df = node_features.loc[train.index]
train_df = pd.DataFrame(
    scaler.fit_transform(train_df),
    index=train_df.index,
    columns=train_df.columns
)

test_df = node_features.loc[test.index]
test_df = pd.DataFrame(
    scaler.transform(test_df),
    index=test_df.index,
    columns=test_df.columns
)

# %%
clf = RandomForestClassifier()
clf.fit(train_df, train['class'])
# Out:
# RandomForestClassifier()

# %%
metrics.f1_score(train['class'], clf.predict(train_df)), \
metrics.f1_score(test['class'], clf.predict(test_df))
# Out:
# (1.0, 0.9872221625684527)

# %% [markdown]
# ## Graph modeling

# %%
# Create graph
edge_index = torch.tensor(edges.values.T, dtype=torch.long)
x = torch.tensor(
    node_features.loc[labeled_data.index].values,
    dtype=torch.float
)
y = torch.tensor(
    labeled_data['class'].values,
    dtype=torch.long
)

data = Data(x=x, edge_index=edge_index, y=y)

# %%
# Split data into train and test sets
train_mask = torch.rand(len(y)) < 0.8
test_mask = ~train_mask

data.train_mask = train_mask
data.test_mask = test_mask

# %%
class GCN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

# %%
model = GCN(input_dim=x.size(1), hidden_dim=16, output_dim=2)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

# %%
# %%time

model.train()
for epoch in range(100):
    optimizer.zero_grad()
    out = model(data)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')
# Out:
# Epoch 1, Loss: 2.371016502380371
# Epoch 2, Loss: 0.7351816296577454
# Epoch 3, Loss: 0.3892441689968109
# Epoch 4, Loss: 0.4281013309955597
# Epoch 5, Loss: 0.5008909106254578
# Epoch 6, Loss: 0.5626734495162964
# Epoch 7, Loss: 0.6069450974464417
# Epoch 8, Loss: 0.6337854862213135
# Epoch 9, Loss: 0.6450944542884827
# Epoch 10, Loss: 0.643189549446106
# Epoch 11, Loss: 0.6305001378059387
# Epoch 12, Loss: 0.609434962272644
# Epoch 13, Loss: 0.5820143818855286
# Epoch 14, Loss: 0.550147294998169
# Epoch 15, Loss: 0.5157629251480103
# Epoch 16, Loss: 0.48056715726852417
# Epoch 17, Loss: 0.44640183448791504
# Epoch 18, Loss: 0.4151143729686737
# Epoch 19, Loss: 0.38844260573387146
# Epoch 20, Loss: 0.36757948994636536
# Epoch 21, Loss: 0.3529711067676544
# Epoch 22, Loss: 0.34415408968925476
# Epoch 23, Loss: 0.3395500183105469
# Epoch 24, Loss: 0.33690616488456726
# Epoch 25, Loss: 0.33374691009521484
# Epoch 26, Loss: 0.3283871114253998
# Epoch 27, Loss: 0.32054659724235535
# Epoch 28, Loss: 0.31121590733528137
# Epoch 29, Loss: 0.3019404113292694
# Epoch 30, Loss: 0.2941349744796753
# Epoch 31, Loss: 0.2885631024837494
# Epoch 32, Loss: 0.2851267457008362
# Epoch 33, Loss: 0.2833438515663147
# Epoch 34, Loss: 0.2825869917869568
# Epoch 35, Loss: 0.28227871656417847
# Epoch 36, Loss: 0.28193023800849915
# Epoch 37, Loss: 0.2812219262123108
# Epoch 38, Loss: 0.279972106218338
# Epoch 39, Loss: 0.27816277742385864
# Epoch 40, Loss: 0.27591681480407715
# Epoch 41, Loss: 0.27344027161598206
# Epoch 42, Loss: 0.27098801732063293
# Epoch 43, Loss: 0.2688029706478119
# Epoch 44, Loss: 0.26704496145248413
# Epoch 45, Loss: 0.2657434344291687
# Epoch 46, Loss: 0.264823853969574
# Epoch 47, Loss: 0.26412898302078247
# Epoch 48, Loss: 0.2634902894496918
# Epoch 49, Loss: 0.2628040015697479
# Epoch 50, Loss: 0.2620222866535187
# Epoch 51, Loss: 0.2611529231071472
# Epoch 52, Loss: 0.26023194193840027
# Epoch 53, Loss: 0.2593223452568054
# Epoch 54, Loss: 0.2584669291973114
# Epoch 55, Loss: 0.25768372416496277
# Epoch 56, Loss: 0.2569738030433655
# Epoch 57, Loss: 0.2563093602657318
# Epoch 58, Loss: 0.2556552290916443
# Epoch 59, Loss: 0.2550002634525299
# Epoch 60, Loss: 0.2543523907661438
# Epoch 61, Loss: 0.25373244285583496
# Epoch 62, Loss: 0.2531646192073822
# Epoch 63, Loss: 0.25266242027282715
# Epoch 64, Loss: 0.2522001266479492
# Epoch 65, Loss: 0.25174480676651
# Epoch 66, Loss: 0.25127649307250977
# Epoch 67, Loss: 0.25079014897346497
# Epoch 68, Loss: 0.25028908252716064
# Epoch 69, Loss: 0.24978144466876984
# Epoch 70, Loss: 0.2492777407169342
# Epoch 71, Loss: 0.24880050122737885
# Epoch 72, Loss: 0.24834613502025604
# Epoch 73, Loss: 0.2479078322649002
# Epoch 74, Loss: 0.24747702479362488
# Epoch 75, Loss: 0.24705389142036438
# Epoch 76, Loss: 0.2466375082731247
# Epoch 77, Loss: 0.2462279051542282
# Epoch 78, Loss: 0.2458215057849884
# Epoch 79, Loss: 0.24541205167770386
# Epoch 80, Loss: 0.24500590562820435
# Epoch 81, Loss: 0.24461452662944794
# Epoch 82, Loss: 0.24424336850643158
# Epoch 83, Loss: 0.24388408660888672
# Epoch 84, Loss: 0.24352899193763733
# Epoch 85, Loss: 0.24317364394664764
# Epoch 86, Loss: 0.2428196221590042
# Epoch 87, Loss: 0.24247431755065918
# Epoch 88, Loss: 0.24213659763336182
# Epoch 89, Loss: 0.241803839802742
# Epoch 90, Loss: 0.24147337675094604
# Epoch 91, Loss: 0.24114927649497986
# Epoch 92, Loss: 0.24083605408668518
# Epoch 93, Loss: 0.24053700268268585
# Epoch 94, Loss: 0.24024678766727448
# Epoch 95, Loss: 0.23995691537857056
# Epoch 96, Loss: 0.23966199159622192
# Epoch 97, Loss: 0.239362895488739
# Epoch 98, Loss: 0.23906296491622925
# Epoch 99, Loss: 0.23876938223838806
# Epoch 100, Loss: 0.2384822517633438
# CPU times: user 3.13 s, sys: 938 ms, total: 4.07 s
# Wall time: 1.32 s

# %%
model.eval()
_, pred = model(data).max(dim=1)
correct = (pred[data.test_mask] == data.y[data.test_mask]).sum()
accuracy = int(correct) / int(data.test_mask.sum())
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 0.9289
